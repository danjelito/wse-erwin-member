# %%
import importlib
from pathlib import Path

import matplotlib.pyplot as plt
from modules import module
import config
import numpy as np
import pandas as pd
import seaborn as sns

try:
    importlib.reload(module)  # reload module
except NameError:
    pass

# %% [markdown]
# # Specify Input

# %%
date= '2024-06-03'# to get parquet

# %% [markdown]
# # Load DF

# %%
path = Path(Path.cwd(), f"output/member_data_{date}.xlsx")
df = pd.read_excel(path)

df.sample(3)
# Out:
#        index                          id                  dob   age  \
# 12513   28.0  SUVIJANA AUDREY 1992-11-27  1992-11-27 00:00:00  30.0
# 14257   26.0                         NaN                  NaN   NaN
# 6282    16.0      JANICE WEN  2000-07-30  2000-07-30 00:00:00  21.0
#
#               phone                      email         gender  \
# 12513  081905588306   suvijanaaudrey@gmail.com  Not Specified
# 14257  081213633820  hotman.tambunan@kpk.go.id  Not Specified
# 6282   081281287997       janicewen1@gmail.com         Female
#
#                     income start_date   end_date  ... active_aug_2023  \
# 12513                  NaN 2023-09-15 2024-09-14  ...           False
# 14257                  NaN 2020-10-01 2020-12-31  ...           False
# 6282   Below Rp 10.000.000 2022-06-06 2023-03-05  ...           False
#
#       active_sep_2023 active_oct_2023 active_nov_2023 active_dec_2023  \
# 12513            True            True            True            True
# 14257           False           False           False           False
# 6282            False           False           False           False
#
#       active_jan_2024 active_feb_2024 active_mar_2024 active_apr_2024  \
# 12513            True            True            True            True
# 14257           False           False           False           False
# 6282            False           False           False           False
#
#       active_may_2024
# 12513            True
# 14257           False
# 6282            False
#
# [3 rows x 50 columns]

# %% [markdown]
# # Other Membership Population

# %%
(df
    .assign(
        product=(
            df["addon_1"].fillna("")
            + " "
            + df["addon_2"].fillna("")
            + " "
            + df["addon_3"].fillna("")
        ).str.strip()
    )
    .groupby("product")
    .sum(numeric_only=True)
    # filer column
    .filter(regex=("active.+"))
    # filter rows
    # filter out ST
    .loc[(lambda df_: ~(df_.index.isin([" ", "", "Street Talk", "Other"])))]
    # clean index name
    .reset_index()
    # rename columns
    .rename(columns=lambda c: c.replace("_", " ").replace("active ", "").title())
    # transpose
    .set_index("Product")
    .transpose()
)
# Out:
# Product   Club  Club IELTS  Club IELTS Proskill  Club Proskill  IELTS  \
# Jan 2023    55           8                    0              3    395
# Feb 2023    65          13                    0              3    397
# Mar 2023    72          16                    0              4    407
# Apr 2023    65          16                    0              4    410
# May 2023    71          17                    0              4    468
# Jun 2023    76          16                    0              6    472
# Jul 2023    86          22                    0              5    488
# Aug 2023   111          32                    0             10    495
# Sep 2023   137          38                    0             12    513
# Oct 2023   151          44                    1             15    534
# Nov 2023   170          49                    2             17    549
# Dec 2023   175          54                    2             18    542
# Jan 2024   196          63                    2             25    553
# Feb 2024   205          65                    2             25    552
# Mar 2024   203          58                    2             25    545
# Apr 2024   190          55                    2             25    522
# May 2024   192          51                    2             24    505
#
# Product   IELTS Proskill  Proskill
# Jan 2023              10       244
# Feb 2023               8       235
# Mar 2023               9       227
# Apr 2023               9       244
# May 2023              10       276
# Jun 2023              10       262
# Jul 2023               9       248
# Aug 2023               9       254
# Sep 2023               8       258
# Oct 2023              10       263
# Nov 2023               9       259
# Dec 2023              10       255
# Jan 2024              11       265
# Feb 2024              11       261
# Mar 2024              13       267
# Apr 2024              13       254
# May 2024              13       251
